# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("lamb2018.csv")

# %%
df.head()
# Out:
#    No. Sex D.O.B      Dam  Sire  Weaning Weight Slaughter/Sale Date  DW  LW  \
# 0  611   F   1/3   675/12   137              42           4/10/2018 NaN NaN
# 1  612   F   1/3   455/16  1621              39                 NaN NaN NaN
# 2  613   F   1/3   455/16  1621              35           30/1/2019 NaN NaN
# 3  614   F   2/3  1128/13   590              21                 NaN NaN NaN
# 4  615   F   2/3  1128/13   590              27                 NaN NaN NaN
#
#   Sold as Store or Breeding  3/7/2018  2/8/2018  6/9/2018  7/11/2018  \
# 0                     Store        42      43.0      49.0        NaN
# 1                       NaN        39      41.0      46.0       56.0
# 2                     Prime        35      37.0      45.0       54.0
# 3                       NaN        21      26.0      32.0       41.0
# 4                       NaN        27      29.0      36.0       45.0
#
#    6/12/2018  10/1/2019  14/2/2019  21/3/2019  18/4/2019      type
# 0        NaN        NaN        NaN        NaN        NaN  pedigree
# 1       50.0       54.0       59.0       64.0       73.0  pedigree
# 2       55.0       56.0       58.0       65.0       74.0  pedigree
# 3       42.0       43.0        NaN        NaN        NaN  pedigree
# 4       44.0       45.0       49.0       54.0       63.0  pedigree

# %%
df.describe()
df.dtypes
# Out:
# No.                            int64
# Sex                           object
# D.O.B                         object
# Dam                           object
# Sire                           int64
# Weaning Weight                 int64
# Slaughter/Sale Date           object
# DW                           float64
# LW                           float64
# Sold as Store or Breeding     object
# 3/7/2018                       int64
# 2/8/2018                     float64
# 6/9/2018                     float64
# 7/11/2018                    float64
# 6/12/2018                    float64
# 10/1/2019                    float64
# 14/2/2019                    float64
# 21/3/2019                    float64
# 18/4/2019                    float64
# type                          object
# dtype: object

# %%
df1 = df

df1['D.O.B'] = df1['D.O.B'].astype(str) #+ '/2016'
df1['D.O.B'] = df1['D.O.B'] + '/2016'
df1['D.O.B']
# Out:
# 0      1/3/2016
# 1      1/3/2016
# 2      1/3/2016
# 3      2/3/2016
# 4      2/3/2016
#         ...
# 75    23/3/2016
# 76    23/3/2016
# 77    27/3/2016
# 78    29/3/2016
# 79    29/3/2016
# Name: D.O.B, Length: 80, dtype: object

# %%
df1['D.O.B'] = pd.to_datetime(df1['D.O.B'], format='%d/%m/%Y')

# %%
df1['D.O.B'][6] - df1['D.O.B'][1]
# Out:
# Timedelta('2 days 00:00:00')

# %%
df_2018 = pd.read_csv("lamb2018.csv")

# %%
df_2018
# Out:
#     No. Sex D.O.B      Dam  Sire  Weaning Weight Slaughter/Sale Date    DW  \
# 0   611   F   1/3   675/12   137              42           4/10/2018   NaN
# 1   612   F   1/3   455/16  1621              39                 NaN   NaN
# 2   613   F   1/3   455/16  1621              35           30/1/2019   NaN
# 3   614   F   2/3  1128/13   590              21                 NaN   NaN
# 4   615   F   2/3  1128/13   590              27                 NaN   NaN
# ..  ...  ..   ...      ...   ...             ...                 ...   ...
# 75  687   M  23/3   443/16  1621              31          21/11/2018  25.6
# 76  688   F  23/3   443/16  1621              31           15/8/2020   NaN
# 77  689   M  27/3   381/15  1621              40          15/10/2019   NaN
# 78  690   F  29/3   386/15  1621              24                 NaN   NaN
# 79  691   F  29/3   326/15  1621              23            8/2/2019  23.1
#
#       LW Sold as Store or Breeding  3/7/2018  2/8/2018  6/9/2018  7/11/2018  \
# 0    NaN                     Store        42      43.0      49.0        NaN
# 1    NaN                       NaN        39      41.0      46.0       56.0
# 2    NaN                     Prime        35      37.0      45.0       54.0
# 3    NaN                       NaN        21      26.0      32.0       41.0
# 4    NaN                       NaN        27      29.0      36.0       45.0
# ..   ...                       ...       ...       ...       ...        ...
# 75  56.0                     Prime        31      35.0      43.0       55.0
# 76   NaN                       NaN        31      33.0      38.0       47.0
# 77   NaN                       NaN        40      37.0      50.0       61.0
# 78   NaN                       NaN        24      25.0      31.0       39.0
# 79  47.0                     Prime        23      26.0      34.0       43.0
#
#     6/12/2018  10/1/2019  14/2/2019  21/3/2019  18/4/2019      type
# 0         NaN        NaN        NaN        NaN        NaN  pedigree
# 1        50.0       54.0       59.0       64.0       73.0  pedigree
# 2        55.0       56.0       58.0       65.0       74.0  pedigree
# 3        42.0       43.0        NaN        NaN        NaN  pedigree
# 4        44.0       45.0       49.0       54.0       63.0  pedigree
# ..        ...        ...        ...        ...        ...       ...
# 75        NaN        NaN        NaN        NaN        NaN  pedigree
# 76       47.0       48.0       52.0       56.0       66.0  pedigree
# 77       61.0       64.0       71.0       79.0       85.0  pedigree
# 78       43.0       42.0       46.0       52.0       60.0  pedigree
# 79       44.0       44.0        NaN        NaN        NaN  pedigree
#
# [80 rows x 20 columns]

# %%
df_2018test = pd.read_csv("lamb2018_test.csv")
df_2018test
# Out:
#     No. D.O.B  3/7/2018  2/8/2018  6/9/2018  7/11/2018  6/12/2018  10/1/2019  \
# 0   611   1/3        42      43.0      49.0        NaN        NaN        NaN
# 1   612   1/3        39      41.0      46.0       56.0       50.0       54.0
# 2   613   1/3        35      37.0      45.0       54.0       55.0       56.0
# 3   614   2/3        21      26.0      32.0       41.0       42.0       43.0
# 4   615   2/3        27      29.0      36.0       45.0       44.0       45.0
# ..  ...   ...       ...       ...       ...        ...        ...        ...
# 75  687  23/3        31      35.0      43.0       55.0        NaN        NaN
# 76  688  23/3        31      33.0      38.0       47.0       47.0       48.0
# 77  689  27/3        40      37.0      50.0       61.0       61.0       64.0
# 78  690  29/3        24      25.0      31.0       39.0       43.0       42.0
# 79  691  29/3        23      26.0      34.0       43.0       44.0       44.0
#
#     14/2/2019  21/3/2019  18/4/2019
# 0         NaN        NaN        NaN
# 1        59.0       64.0       73.0
# 2        58.0       65.0       74.0
# 3         NaN        NaN        NaN
# 4        49.0       54.0       63.0
# ..        ...        ...        ...
# 75        NaN        NaN        NaN
# 76       52.0       56.0       66.0
# 77       71.0       79.0       85.0
# 78       46.0       52.0       60.0
# 79        NaN        NaN        NaN
#
# [80 rows x 11 columns]

# %%
# Convert 'D.O.B' to datetime

df_2018test['D.O.B'] = df_2018test['D.O.B'].astype(str) #+ '/2016'
df_2018test['D.O.B'] = df_2018test['D.O.B'] + '/2018'


df_2018test['D.O.B'] = pd.to_datetime(df_2018test['D.O.B'], format='%d/%m/%Y')

# Extract the columns that have dates
date_columns = df_2018test.columns[2:]

# Initialize lists to store the results
lambs_list = []
age_list = []
weight_list = []

# Calculate the Age (Days) and Weight
for col in date_columns:
    age_days = (pd.to_datetime(col, format='%d/%m/%Y') - df_2018test['D.O.B']).dt.days
    lambs_list.extend(df_2018test['No.'])
    age_list.extend(age_days)
    weight_list.extend(df_2018test[col])

# Create the final DataFrame
final_df1 = pd.DataFrame({
    'No.': lambs_list,
    'Age (Days)': age_list,
    'Weight': weight_list
})

final_df1.sort_values(by=['No.', 'Age (Days)'], inplace=True)
final_df1.reset_index(drop=True, inplace=True)

print(final_df1)
# Out:
#      No.  Age (Days)  Weight
# 0    611         124    42.0
# 1    611         154    43.0
# 2    611         189    49.0
# 3    611         251     NaN
# 4    611         280     NaN
# ..   ...         ...     ...
# 715  691         252    44.0
# 716  691         287    44.0
# 717  691         322     NaN
# 718  691         357     NaN
# 719  691         385     NaN
#
# [720 rows x 3 columns]

# %%
# Plotting the Curve
plt.figure(figsize=(20, 20))

for lamb_no in final_df1['No.'].unique():
    lamb_data = final_df1[final_df1['No.'] == lamb_no]
    plt.plot(lamb_data['Age (Days)'], lamb_data['Weight'], marker='o', label=f'Lamb {lamb_no}')

plt.title('Growth Curve of Lambs', fontsize=24)
plt.xlabel('Age (Days)', fontsize=20)
plt.ylabel('Weight', fontsize=20)
#plt.legend()
plt.grid(True)
plt.show()

# %%
#Sample with only two Lambs
df_2018testtr = pd.read_csv("lamb2018_testtr.csv")
df_2018testtr
# Out:
#    No. D.O.B  3/7/2018  2/8/2018  6/9/2018  7/11/2018  6/12/2018  10/1/2019  \
# 0  611   1/3        42        43        49        NaN        NaN        NaN
# 1  612   1/3        39        41        46       56.0       50.0       54.0
#
#    14/2/2019  21/3/2019  18/4/2019
# 0        NaN        NaN        NaN
# 1       59.0       64.0       73.0

# %%
# Convert 'D.O.B' to datetime

df_2018testtr['D.O.B'] = df_2018testtr['D.O.B'].astype(str) #+ '/2016'
df_2018testtr['D.O.B'] = df_2018testtr['D.O.B'] + '/2018'


df_2018testtr['D.O.B'] = pd.to_datetime(df_2018testtr['D.O.B'], format='%d/%m/%Y')

# Extract the columns that have dates
date_columns = df_2018testtr.columns[2:]

# Initialize lists to store the results
lambs_list = []
age_list = []
weight_list = []

# Calculate the Age (Days) and Weight
for col in date_columns:
    age_days = (pd.to_datetime(col, format='%d/%m/%Y') - df_2018testtr['D.O.B']).dt.days
    lambs_list.extend(df_2018testtr['No.'])
    age_list.extend(age_days)
    weight_list.extend(df_2018testtr[col])

# Create the final DataFrame
final_df2 = pd.DataFrame({
    'No.': lambs_list,
    'Age (Days)': age_list,
    'Weight': weight_list
})

final_df2.sort_values(by=['No.', 'Age (Days)'], inplace=True)
final_df2.reset_index(drop=True, inplace=True)

print(final_df2)
# Out:
#     No.  Age (Days)  Weight
# 0   611         124    42.0
# 1   611         154    43.0
# 2   611         189    49.0
# 3   611         251     NaN
# 4   611         280     NaN
# 5   611         315     NaN
# 6   611         350     NaN
# 7   611         385     NaN
# 8   611         413     NaN
# 9   612         124    39.0
# 10  612         154    41.0
# 11  612         189    46.0
# 12  612         251    56.0
# 13  612         280    50.0
# 14  612         315    54.0
# 15  612         350    59.0
# 16  612         385    64.0
# 17  612         413    73.0

# %%
#Plotting the curve For all the lambs
plt.figure(figsize=(10, 6))

for lamb_no in final_df2['No.'].unique():
    lamb_data = final_df2[final_df2['No.'] == lamb_no]
    plt.plot(lamb_data['Age (Days)'], lamb_data['Weight'], marker='o', label=f'Lamb {lamb_no}')

plt.title('Growth Curve of Lambs')
plt.xlabel('Age (Days)')
plt.ylabel('Weight')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Nadaraya–Watson Estimator on two lambs dataset
from scipy.stats import norm

def gaussian_kernel(distance, bandwidth):
    return norm.pdf(distance / bandwidth)

def nadaraya_watson(x, X, Y, bandwidth):
    weights = gaussian_kernel(x - X, bandwidth)
    return np.sum(weights * Y) / np.sum(weights)

def estimate_weight(lamb_no, target_age, bandwidth):
    lamb_data = final_df2[final_df2['No.'] == lamb_no].dropna(subset=['Weight'])
    X = lamb_data['Age (Days)'].values
    Y = lamb_data['Weight'].values
    estimated_weight = nadaraya_watson(target_age, X, Y, bandwidth)
    return estimated_weight

# Example: Estimating the weight of lamb 611 at age 200 days
lamb_no = 611
target_age = 200
bandwidth = 30  # Bandwidth Adjustment

estimated_weight = estimate_weight(lamb_no, target_age, bandwidth)
print(f"Estimated weight of lamb {lamb_no} at age {target_age} days: {estimated_weight}")
# Out:
# Estimated weight of lamb 611 at age 200 days: 47.33751191658829

# %%
lamb_no = 611
lamb_data1 = final_df1[final_df1['No.'] == lamb_no].dropna(subset=['Weight'])
print(lamb_data1)
# Out:
#    No.  Age (Days)  Weight
# 0  611         124    42.0
# 1  611         154    43.0
# 2  611         189    49.0

# %%
# Nadaraya–Watson Estimator on Larger Dataset with guassian weights
from scipy.stats import norm

def gaussian_kernel(distance, bandwidth):
    return norm.pdf(distance / bandwidth)


def nadaraya_watson(x, X, Y, bandwidth):
    weights = gaussian_kernel(x - X, bandwidth)
    return np.sum(weights * Y) / np.sum(weights)

def estimate_weight(lamb_no, target_age, bandwidth):
    lamb_data = final_df1[final_df1['No.'] == lamb_no].dropna(subset=['Weight'])
    X = lamb_data['Age (Days)'].values
    Y = lamb_data['Weight'].values
    estimated_weight = nadaraya_watson(target_age, X, Y, bandwidth)
    return estimated_weight

# Example: Estimating the weight of lamb 611 at age 200 days
lamb_no = 611
target_age = 200
bandwidth = 30  # Bandwidth Adjustment

estimated_weight = estimate_weight(lamb_no, target_age, bandwidth)
print(f"Estimated weight of lamb {lamb_no} at age {target_age} days: {estimated_weight}")
# Out:
# Estimated weight of lamb 611 at age 200 days: 47.33751191658829

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# Function to compute Gaussian kernel
def gaussian_kernel(distance, bandwidth):
    return norm.pdf(distance / bandwidth)

# Function to compute Nadaraya-Watson estimate
def nadaraya_watson(x, X, Y, bandwidth):
    weights = gaussian_kernel(x - X, bandwidth)
    return np.sum(weights * Y) / np.sum(weights)

# Function to estimate weight for a given lamb and target age
def estimate_weight(lamb_no, target_age, bandwidth):
    lamb_data = final_df2[final_df2['No.'] == lamb_no].dropna(subset=['Weight'])
    X = lamb_data['Age (Days)'].values
    Y = lamb_data['Weight'].values
    estimated_weight = nadaraya_watson(target_age, X, Y, bandwidth)
    return estimated_weight

# Estimating the weight curve for lamb
def estimate_weight_curve(lamb_no, X, bandwidth):
    estimated_weights = []
    for age in X:
        estimated_weight = estimate_weight(lamb_no, age, bandwidth)
        estimated_weights.append(estimated_weight)
    return np.array(estimated_weights)

# Define the lamb number and the age range for estimation
lamb_no = 612
X = np.arange(0, 450, 1)  # Estimating weights from day 0 to 300
bandwidth = 30  # Bandwidth Adjustment

# Estimate the weight curve
estimated_weights = estimate_weight_curve(lamb_no, X, bandwidth)

# Plot the actual data and the estimated curve
plt.figure(figsize=(12, 6))
lamb_data = final_df2[final_df2['No.'] == lamb_no]
plt.plot(lamb_data['Age (Days)'], lamb_data['Weight'], 'o', label=f'Actual Data (Lamb {lamb_no})')
plt.plot(X, estimated_weights, label='Estimated Curve', color='red', linestyle='--')

plt.title('Estimated Growth Curve of Lamb 612')
plt.xlabel('Age (Days)')
plt.ylabel('Weight')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting the curve:
# Plotting the curve:

plt.figure(figsize=(10, 6))

for lamb_no in final_df2['No.'].unique():
    lamb_data = final_df2[final_df2['No.'] == lamb_no]
    plt.plot(lamb_data['Age (Days)'], lamb_data['Weight'], label=f'Lamb {lamb_no}', alpha=0.6)

# Plot the estimated weight
plt.scatter(target_age, estimated_weight, color='red', label=f'Estimated Weight at {target_age} days', zorder=5)

plt.title('Growth Curve of Lambs with Nadaraya Watson Estimation')
plt.xlabel('Age (Days)')
plt.ylabel('Weight')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Using e^-c weights

# %%
import numpy as np

def weight_function(age, target_age, c):
    return np.exp(-c * (age - target_age)**2)

def nadaraya_watson_normalized(target_age, X, Y, c):
    # Calculate weights using the weight function
    weights = weight_function(X, target_age, c)
    # Normalize the weights so that they sum to 1
    normalized_weights = weights / np.sum(weights)
    
    # Calculate the weighted average of Y
    estimated_weight = np.sum(normalized_weights * Y)
    
    return estimated_weight

def estimate_weight_nadaraya_watson(lamb_no, target_age, c):
    lamb_data = final_df2[final_df2['No.'] == lamb_no].dropna(subset=['Weight'])
    X = lamb_data['Age (Days)'].values
    Y = lamb_data['Weight'].values
    estimated_weight = nadaraya_watson_normalized(target_age, X, Y, c)
    return estimated_weight

# Example: Estimate the weight of lamb 611 at age 200 days
lamb_no = 612
target_age = 200
c = 0.001  # You can adjust the value of c

estimated_weight = estimate_weight_nadaraya_watson(lamb_no, target_age, c)
print(f"Estimated weight of lamb {lamb_no} at age {target_age} days: {estimated_weight}")
# Out:
# Estimated weight of lamb 612 at age 200 days: 46.11458465221574

# %%
# Plotting the curve:

plt.figure(figsize=(10, 6))

for lamb_no in final_df2['No.'].unique():
    lamb_data = final_df2[final_df2['No.'] == lamb_no]
    plt.plot(lamb_data['Age (Days)'], lamb_data['Weight'], label=f'Lamb {lamb_no}', alpha=0.6)

# Plot the estimated weight
plt.scatter(target_age, estimated_weight, color='red', label=f'Estimated Weight at {target_age} days', zorder=5)

plt.title('Growth Curve of Lambs with Nadaraya Watson Estimation')
plt.xlabel('Age (Days)')
plt.ylabel('Weight')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Local Linear Fit:

from sklearn.linear_model import LinearRegression

def weight_function(age, target_age, c):
    return np.exp(-c * (age - target_age)**2)


def weighted_local_linear_fit(target_age, X, Y, c):
    weights = weight_function(X, target_age, c)
    
    # Fit a weighted linear regression model
    model = LinearRegression()
    X_reshaped = X.reshape(-1, 1)
    model.fit(X_reshaped, Y, sample_weight=weights)
    
    # Predict the weight at the target age
    predicted_weight = model.predict([[target_age]])
    return predicted_weight[0]

# %%
#Fitting the model

def estimate_weight_local_linear(lamb_no, target_age, c):
    lamb_data = final_df2[final_df2['No.'] == lamb_no].dropna(subset=['Weight'])
    X = lamb_data['Age (Days)'].values
    Y = lamb_data['Weight'].values
    estimated_weight = weighted_local_linear_fit(target_age, X, Y, c)
    return estimated_weight

# Example: Estimate the weight of lamb 611 at age 200 days
lamb_no = 612
target_age = 200
c = 0.001  # You can adjust the value of c

estimated_weight = estimate_weight_local_linear(lamb_no, target_age, c)
print(f"Estimated weight of lamb {lamb_no} at age {target_age} days: {estimated_weight}")
# Out:
# Estimated weight of lamb 612 at age 200 days: 47.72162598850616

# %%
# Plotting the curve:

plt.figure(figsize=(10, 6))

for lamb_no in final_df2['No.'].unique():
    lamb_data = final_df2[final_df2['No.'] == lamb_no]
    plt.plot(lamb_data['Age (Days)'], lamb_data['Weight'], label=f'Lamb {lamb_no}', alpha=0.6)

# Plot the estimated weight
plt.scatter(target_age, estimated_weight, color='red', label=f'Estimated Weight at {target_age} days', zorder=5)

plt.title('Growth Curve of Lambs with Weighted Local Linear Fit Estimation')
plt.xlabel('Age (Days)')
plt.ylabel('Weight')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Local Linear Fit:

from sklearn.linear_model import LinearRegression

def weight_function(age, target_age, c):
    return np.exp(-c * (age - target_age)**2)


def weighted_local_linear_fit(target_age, X, Y, c):
    weights = weight_function(X, target_age, c)
    
    # Fit a weighted linear regression model
    model = LinearRegression()
    X_reshaped = X.reshape(-1, 1)
    model.fit(X_reshaped, Y, sample_weight=weights)
    
    # Predict the weight at the target age
    predicted_weight = model.predict([[target_age]])
    return predicted_weight[0]

#Fitting the model

def estimate_weight_local_linear(lamb_no, target_age, c):
    lamb_data = final_df1[final_df1['No.'] == lamb_no].dropna(subset=['Weight'])
    X = lamb_data['Age (Days)'].values
    Y = lamb_data['Weight'].values
    estimated_weight = weighted_local_linear_fit(target_age, X, Y, c)
    return estimated_weight

# Example: Estimate the weight of lamb 611 at age 200 days
lamb_no = 689
target_age = 163
c = 0.001  # You can adjust the value of c

estimated_weight = estimate_weight_local_linear(lamb_no, target_age, c)
print(f"Estimated weight of lamb {lamb_no} at age {target_age} days: {estimated_weight}")

# Plotting the curve:

plt.figure(figsize=(10, 6))

for lamb_no in final_df1['No.'].unique():
    lamb_data = final_df1[final_df1['No.'] == lamb_no]
    plt.plot(lamb_data['Age (Days)'], lamb_data['Weight'], label=f'Lamb {lamb_no}', alpha=0.6)

# Plot the estimated weight
plt.scatter(target_age, estimated_weight, color='red', label=f'Estimated Weight at {target_age} days', zorder=5)

plt.title('Growth Curve of Lambs with Weighted Local Linear Fit Estimation')
plt.xlabel('Age (Days)')
plt.ylabel('Weight')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Estimated weight of lamb 689 at age 163 days: 49.436244383728194
